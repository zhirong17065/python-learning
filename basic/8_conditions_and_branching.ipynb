# %%
# Comparison operators
a = 6
condition = 6
# Equal
print(a == condition) # True
# Not equal
print(a != condition) # False
# Greater than
print(a > condition) # False
# Less than
print(a < condition) # False
# Greater than or equal to
print(a >= condition) # True
# Less than or equal to
print(a <= condition) # True
# Out:
# True
# False
# False
# False
# True
# True

# %%
# Compare strings
# The strings are compared by the ASCII value of the characters
print('B' > 'A') # True
print('BA ' > 'AB') # True
print('AA' > 'AB') # False
print('AA' > 'AAB') # False
# Out:
# True
# True
# False
# False

# %%
# Branching
# if statement
# Get age from user
age = int(input("Enter your age: "))
if age > 18:
    print("You can enter")
elif age == 18:
    print("go see Pink Floyd")
else:
    print("go see Meat Loaf")

print("move on")
# Out:
# You can enter
# move on

# %%
# Logic operators
# Not
print(not(True)) # False
print(not(False)) # True

# Or
print(False or False) # False
print(False or True) # True
print(True or False) # True
print(True or True) # True

# And
print(False and False) # False
print(False and True) # False
print(True and False) # False  
print(True and True) # True
# Out:
# False
# True
# False
# True
# True
# True
# False
# False
# False
# True

# %%
# Example for logic operators
album_year = 1990
if album_year < 1980 or album_year > 1989:
    print("The album was made in the 70's or 90's")
else:
    print("The album was made in the 80's")

album_year = 1983
if album_year > 1979 and album_year < 1990:
    print("The album was made in the 80's")
# Out:
# The album was made in the 70's or 90's
# The album was made in the 80's
