# %% [markdown]
# <h1>2D Numpy</h1>

# %%
import numpy as np

# %%
a = [[11,12,13],[21,22,23],[31,32,33]]
A = np.array(a)
print(A)
print(A.ndim)
print(A.shape)
print(A.size)

# Accessing using index
print(A[0,0]) # [row, column]
print(A[1,2]) # [row, column]
# Out:
# [[11 12 13]
#  [21 22 23]
#  [31 32 33]]
# 2
# (3, 3)
# 9
# 11
# 23

# %% [markdown]
# <h3>Slicing</h3>

# %%
# Slicing
B = A[0:2,1:3] # [row_start:row_end, column_start:column_end]
print(B)
# Out:
# [[12 13]
#  [22 23]]

# %% [markdown]
# <h3>Adding 2D arrays</h3>

# %%
X = np.array([[1,0],[0,1]])
Y = np.array([[2,1],[1,2]])
Z = np.add(X,Y)
print(Z)
# Out:
# [[3 1]
#  [1 3]]

# %% [markdown]
# <h3>Multiplying 2D arrays</h3>

# %%
X = np.array([[1,0],[0,1]])
Y = np.array([[2,1],[1,2]])

Z = 2 * Y
print(Z)

Z = X * Y
print(Z)
# Out:
# [[4 2]
#  [2 4]]
# [[2 0]
#  [0 2]]

# %% [markdown]
# <h3>Matrix multiplication</h3>

# %%
A = np.array([[0, 1, 1], [1, 0, 1]])
B = np.array([[1, 1], [1, 1], [-1, 1]])

Z = np.dot(A,B)
Z
# Out:
# array([[0, 2],
#        [0, 2]])

# %% [markdown]
# <h3>Transpose</h3>

# %%
C = np.array([[1,1],[2,2],[3,3]])
print(C)
print(C.T)
# Out:
# [[1 1]
#  [2 2]
#  [3 3]]
# [[1 2 3]
#  [1 2 3]]
