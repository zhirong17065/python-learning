# %% [markdown]
# <h1>Pandas: Loading Data</h1>

# %%
# Importing pandas library
import pandas as pd
# Load csv file
csv_path = "resources/csv/file1.csv"
df = pd.read_csv(csv_path,sep='\s+')
df.head()

# Load excel file
excel_path = "resources/excel/file1.xlsx"
# df = pd.read_excel(excel_path)

# %%
# Dataframe
# Dataframe is a comprised of rows and columns.
df = pd.read_csv(csv_path, sep='\s+')
df.head()

# Create a dataframe from a dictionary
# Keys for header columns and values for rows
songs = {
    'Album': ['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell'],
    'Released': [1982, 1980, 1973, 1992, 1977],
    'Length': ['00:42:19', '00:42:11', '00:43:00', '00:57:44', '00:46:33']
}
songs_frame = pd.DataFrame(songs)

# Create a dataframe from another dataframe
x = songs_frame[['Album', 'Released']]

# %%
# Access data in df
print(df.iloc[0,0]) # First row, first column
print(df.iloc[1,0]) # Second row, first column

# Access using column name
print(df.loc[0, 'Value']) # First row, Name column

# set index
df_new = df
df_new.index = ['a', 'b', 'c']
print(df.loc['a', 'Value'])
# Out:
# 0
# 1
# 1
# 1

# %%
# Slice dataframe
z = df.iloc[0:2, 0:3] # First two rows, first three columns
z = df.loc[0:2, 'Name':'Value'] # First three rows, Name to Value columns
