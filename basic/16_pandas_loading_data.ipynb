# %% [markdown]
# <h1>Pandas: Loading Data</h1>

# %%
# Importing pandas library
import pandas as pd
# Load csv file
csv_path = "resources/csv/file1.csv"
df = pd.read_csv(csv_path)

# Load excel file
excel_path = "resources/excel/file1.xlsx"
df = pd.read_excel(excel_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       7 # Load excel file
#       8 excel_path = "resources/excel/file1.xlsx"
# ----> 9 df = pd.read_excel(excel_path)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_base.py:1554, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
# -> 1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#    1559 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1560 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
# Dataframe
# Dataframe is a comprised of rows and columns.
df = pd.read_csv(csv_path)
df.head()

# Create a dataframe from a dictionary
songs = {
    'Album': ['Thriller', 'Back in Black', 'The Dark Side of the Moon', 'The Bodyguard', 'Bat Out of Hell'],
    'Released': [1982, 1980, 1973, 1992, 1977],
    'Length': ['00:42:19', '00:42:11', '00:43:00', '00:57:44', '00:46:33']
}
songs_frame = pd.DataFrame(songs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Dataframe
#       2 # Dataframe is a comprised of rows and columns.
# ----> 3 df = pd.read_csv(csv_path)
#       4 df.head()
#       6 # Create a dataframe from a dictionary
#
# NameError: name 'pd' is not defined
