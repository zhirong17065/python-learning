# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
# This is a comment
print("Hello, world!")
# Out:
# Hello, world!

# %%
# Print with parameters
z = 2 + 5
print("The value of z is", z)
# Out:
# The value of z is 7
