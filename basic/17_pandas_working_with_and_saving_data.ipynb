# %%
import pandas as pd
df = pd.read_csv("resources/csv/songs.csv", sep=';')
df.head()
# Out:
#                                            Artist    Album  \
# Micheal Jackson Thriller                     1982  0:42:19
# AC/DC           Back in Black                1980  0:42:11
# Pink Floyd      The Dark Side of the Moon    1973  0:42:49
# Whitney Houston  The Bodyguard               1992  0:57:44
# Meaf Loaf       Bat Out of Hell              1977  0:43:08
#
#                                                               Released  \
# Micheal Jackson Thriller                                pop, rock, R&B
# AC/DC           Back in Black                                hard rock
# Pink Floyd      The Dark Side of the Moon             progressive rock
# Whitney Houston  The Bodyguard                          R&B, soul, pop
# Meaf Loaf       Bat Out of Hell            hard rock, progressive rock
#
#                                            Length  Genre  \
# Micheal Jackson Thriller                     46.0     65
# AC/DC           Back in Black                26.1     50
# ...
